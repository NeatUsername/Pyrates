# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
from time import sleep
import pymongo

# Setup Mongo DB to store and later export array as JSON
# conn = 'mongodb://localhost:27017'
# client = pymongo.MongoClient(conn)
# db = client.pyrates_db
# collection = db.items

# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

url = 'https://www.icc-ccs.org/index.php/piracy-reporting-centre/live-piracy-report/details/179/'


# browser.visit(url)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 89.0.4389
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - Trying to download new driver from https://chromedriver.storage.googleapis.com/89.0.4389.23/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\simon\.wdm\drivers\chromedriver\win32\89.0.4389.23]

# %%
# Need to build a loop that will iterate from #4 to #2101, and append that value to our
# URL.  We'll need to build in a wait timer to prevent the server from blocking our IP
# in the process.

for x in range(4,10):
    
    try:
        
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        visit_url = url + str(x)
        
        browser.visit(visit_url)
        sleep(2)
        
        if soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___date_of_incident_ro').text == "":
            incident_date = "null"
        if soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___date_of_incident_ro').text != "":
            incident_date = soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___date_of_incident_ro').text
            
        if soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___type_attack_ro').text == "":
            type_of_attack = "null"
        if soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___type_attack_ro').text != "":
            type_of_attack = soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___type_attack_ro').text
            
        if soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___type_ro').text == "":
            type_of_vessel = "null"
        if soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___type_ro').text != "":
            type_of_vessel = soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___type_ro').text
            
        if soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___attack_no_ro').text == "":
            attack_num = "null"
        if soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___attack_no_ro').text != "":
            attack_num = soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___attack_no_ro').text
            
#         if soup.find('input', class_='latdms').get('value') == "":
#             lat_dms = "null"
        if soup.find('input', {'class':'latdms', 'class':'value'}) == "":
            lat_dms = "null"
#         if soup.find('input', class_='latdms').get('value') != "":
#             lat_dms = soup.find('input', class_='latdms').get('value')
            
#         if soup.find('input', class_='lngdms').get('value') == "":
#             long_dms = "null"
#         if soup.find('input', class_='lngdms').get('value') != "":
#             long_dms = soup.find('input', class_='lngdms').get('value')
            
        if soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___narrations_ro').text == "":
            narrative = "null"
        if soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___narrations_ro').text != "":
            narrative = soup.find('div', id='jos_fabrik_icc_ccs_piracymap2016___narrations_ro').text
        
        
    
        #browser.visit(visit_url)
    
        print("URL: " + visit_url)
        print("==============================")
        # Print results
        print("Incident Date: " + incident_date)
        print("Type of Attack: " + type_of_attack)
        print("Type of Vessel: " + type_of_vessel)
        print("Attack Number: " + attack_num)
        print("Latitude: " + lat_dms)
        print("Longitude: " + long_dms)
        print("Narrative: " + narrative)
        print("                             ")
        
        # Dictionary to be inserted as a MongoDB document
#         entry = {
#             'Incident Date': incident_date,
#             'Type of Attack': type_of_attack,
#             'Type of Vessel': type_of_vessel,
#             'Attack Number': attack_num,
#             'Latitude DMS': lat_dms,
#             'Longitude DMS': long_dms,
#             'Narrative': narrative
#         }

#         collection.insert_one(entry)
        
        
    
    except Exception as e:
        print(e)
    
    sleep(3)
# Out:
# URL: https://www.icc-ccs.org/index.php/piracy-reporting-centre/live-piracy-report/details/179/4
# ==============================
# Incident Date:
# Type of Attack: Suspicious
# Type of Vessel: Ro-Ro
# Attack Number: SUS - 003
# Latitude: N13°54’58
# Longitude: W90°44’50
# Narrative: SUSPICIOUS CRAFT: This incident will not be included in the IMB statistics
#
# 05.04.2014: 0832 UTC: Posn: 20:15.00N – 059:02.30E, Around 15nm East of Masirah Island, Oman.
# Two skiffs and a dhow approached a Ro-Ro cargo ship underway. Master raised alarm, increased speed, sounded ship’s whistle and the non-essential crew mustered in the citadel. The onboard armed security team fired warning shots but as the skiffs continued their approach at a distance of 0.25nm the armed team fired more warning shots resulting in the skiffs aborting the approach and moving away.
#
# URL: https://www.icc-ccs.org/index.php/piracy-reporting-centre/live-piracy-report/details/179/5
# ==============================
# Incident Date:
# Type of Attack: Attempted
# Type of Vessel: General Cargo
# Attack Number: 267
# Latitude: N13°54’58
# Longitude: W90°44’50
# Narrative: 21.11.2012: 2325 LT: Posn: 06:03.36N – 001:16.46E, Lome anchorage, Togo.
# Six robbers in three unlit boats approached an anchored general cargo ship twice in around 30 minutes. The boats hid behind the bunker barge before approaching the vessel from the port and stbs sides. On both occasions the boats were unsuccessful due to the vigilance of the crew, hardening of the vessel and the presence of security personal. On reporting to port control a navy boat was sent out for inspection.
#
# URL: https://www.icc-ccs.org/index.php/piracy-reporting-centre/live-piracy-report/details/179/6
# ==============================
# Incident Date:
# Type of Attack: Suspicious
# Type of Vessel: General Cargo
# Attack Number: NA
# Latitude: N13°54’58
# Longitude: W90°44’50
# Narrative: This sitrep will not be included in the IMB stats.
#
# 22.12.2017: 0318 UTC: Puerto Quetzal Anchorage, Guatemala.
# Duty crew on routine rounds noticed a speed boat with two persons approach the vessel from astern. The speedboat disappeared under the stern of the ship. Later the duty crew noticed two more persons wearing diving suites with a package boarding the speed boat. The incident was reported to the port control. The authorities from the harbour master’s office boarded the vessel and conducted an investigation in and around the ship. Their divers found a black package near the ship's seachest.
#
# URL: https://www.icc-ccs.org/index.php/piracy-reporting-centre/live-piracy-report/details/179/7
# ==============================
# Incident Date:
# Type of Attack: null
# Type of Vessel: null
# Attack Number: null
# Latitude: N13°54’58
# Longitude: W90°44’50
# Narrative: null
#
# URL: https://www.icc-ccs.org/index.php/piracy-reporting-centre/live-piracy-report/details/179/8
# ==============================
# Incident Date:
# Type of Attack: null
# Type of Vessel: null
# Attack Number: null
# Latitude: N13°54’58
# Longitude: W90°44’50
# Narrative: null
#
# URL: https://www.icc-ccs.org/index.php/piracy-reporting-centre/live-piracy-report/details/179/9
# ==============================
# Incident Date:
# Type of Attack: null
# Type of Vessel: null
# Attack Number: null
# Latitude: N13°54’58
# Longitude: W90°44’50
# Narrative: null
